# %%
import toolbox as tb
import tensorflow as tf

# %%
IMAGE_SHAPE = (224, 224)

# %%
# model_name = "mon_modele"
model_name = "mon_modele__5_labels"
# model_path = f"tutorials/mes_modeles/{model_name}.h5"
model_path = f"mes_modeles/{model_name}"

# %%
model = tf.keras.models.load_model(model_path)

# model.summary()

# %%
image_path = "tutorials/test_images/pizza.jpg"
image = tb.get_image(image_path=image_path, shape=(224, 224))

image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
label = tb.predict_image(model=model, image_path=image_path, shape=IMAGE_SHAPE)

label
# Out:
# Found 3000 files belonging to 5 classes.
# 1/1 [==============================] - 1s 514ms/step
# 'pizza'
